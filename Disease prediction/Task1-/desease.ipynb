# %%
import pandas as pd
import numpy as np

# %%
print("Ai diagnosis Assistant activated...")
print("input only (YES/NO)")
f=input("do you have a fever:")
c=input("do you have a cough:")
h=input("do you have a headache:")
ft=input("do you feel fatigue/tiredness?:")
v=input("do you have a vomiting?")
cp=input("do you have a Chest pain?")
bd=input("do you have a Breathing difficulty?")
bop=input("do you have a body pain?")
t=input("do you feel excessive thirst?")
u=input("do you have frequent urination?")
st=input("do you have sore throat ?")
sp=input("do you have stomach pain?")
d=input("do you have dizziness?")
sh=input("do you have shivering?")
sw=input("do you have sweating?")
bl=input("do you have bloating?")


print("Analysing symptoms.....")
if f=='yes' and c=='yes' and st=='yes' :
    print("possible disease:/n common cold")
    print("Severity :Mild")
    print("Suggestion: takea rest")

elif f=='yes' and bod=='yes' and ft=='yes' and hd=='yes' :
    print("possible disease:/n Flu")
    print("Severity :Moderate")
    print("Suggestion: takea rest or consult doctor")

elif f=='yes' and c=='yes' and ft=='yes' and bd=='yes' :
    print("possible disease:/n COVID like infection")
    print("Severity : Severe")
    print("Suggestion: consult doctor")

elif f=='yes' and v=='yes' and sp=='yes' :
    print("possible disease:/n Food poisoning")
    print("Severity : moderate")
    print("Suggestion: consult doctor")

elif h=='yes' and v=='yes' and d=='yes' :
    print("possible disease:/n Migraine")
    print("Severity :mild/ moderate")
    print("Suggestion: consult doctor")

elif u=='yes' and t=='yes' and ft=='yes' :
    print("possible disease:/n Diabites Risk")
    print("Severity : severe")
    print("Suggestion: consult doctor")

elif cp=='yes' and bd=='yes' and d=='yes' :
    print("possible disease:/n Heart Disease Risk")
    print("Severity : severe")
    print("Suggestion: consult doctor")

elif f=='yes' and bop=='yes' and h=='yes' and v=='yes' :
    print("possible disease:/n Dengue like symptoms!")
    print("Severity : severe")
    print("Suggestion: consult doctor")

elif f=='yes' and sh=='yes' and sw=='yes' and h=='yes' :
    print("possible disease:/n Malaria like!")
    print("Severity : Moderate/severe")
    print("Suggestion: consult doctor")

elif sp=='yes' and v=='yes' and bl=='yes' :
    print("possible disease:/n Gastric problem!")
    print("Severity : mild")
    print("Suggestion: consult doctor")

elif bd=='yes' and c=='yes' and cp=='yes' :
    print("possible disease:/n Asthma Risk!")
    print("Severity : Severe")
    print("Suggestion: consult doctor immediately")

elif d=='yes' and ft=='yes' and t=='yes' :
    print("possible disease:/n Dehydration!")
    print("Severity : Mild/Moderate")
    print("Suggestion: Drink Water You are not cactus!!")

else :
    print("major disease Not found!!")
# Out:
# Ai diagnosis Assistant activated...
# input only (YES/NO)
# do you have a fever: no
# do you have a cough: no
# do you have a headache: no
# do you feel fatigue/tiredness?: yes
# do you have a vomiting? no
# do you have a Chest pain? no
# do you have a Breathing difficulty? no
# do you have a body pain? no
# do you feel excessive thirst? yes
# do you have frequent urination? no
# do you have sore throat ? no
# do you have stomach pain? no
# do you have dizziness? yes
# do you have shivering? no
# do you have sweating? no
# do you have bloating? no
# Analysing symptoms.....
# possible disease:/n Dehydration!
# Severity : Mild/Moderate
# Suggestion: Drink Water You are not cactus!!
